# %% [markdown]
# # Black–Scholes model 에서의 주가변동

# %% [markdown]
# ## $$ \frac{dS}{S} = \mu dt + \sigma db $$

# %%
import numpy as np
np.random.seed(10)

s0 = 100 #초기값. 초기 주가값.
mu = 0.1 #10%. expected return.
sigma = 0.3 #30%. 작으면 변동이 덜하고 크면 변동이 크다.
T = 2 #몇 년동안 simulation 할 것인가. 만기 시기.
n = 12*21 #1년은 12달, 1달은 21일의 business day로 이루어져 있다.
dt = 1/n
n_sample_paths = 10

# %%
pm_one = 2*np.random.binomial(1, 0.5, size=(n*T, n_sample_paths)) -1 #50% 확률로 +-1이 나오도록 지정
db = pm_one * np.sqrt(dt)

lhs = mu*dt + sigma*db
time = np.arange(n*T +1) * dt
stock = np.empty( (n*T+1, n_sample_paths)) #stock_price?
stock[0] = s0
for t in range(n*T) :
    stock[t+1] = stock[t] + stock[t]*lhs[t]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

for i in range(n_sample_paths) :
    plt.plot(time, stock[:, i])

plt.plot(time, stock)
plt.show()

# %% [markdown]
# # 2년 후 주가의 분포

# %%
import numpy as np
np.random.seed(10)

s0 = 100 #초기값. 초기 주가값.
mu = 0.1 #10%. expected return.
sigma = 0.3 #30%. 작으면 변동이 덜하고 크면 변동이 크다.
T = 2 #몇 년동안 simulation 할 것인가. 만기 시기.
n = 12*21 #1년은 12달, 1달은 21일의 business day로 이루어져 있다.
dt = 1/n
n_sample_paths = 10000

# %%
pm_one = 2*np.random.binomial(1, 0.5, size=(n*T, n_sample_paths)) -1 #50% 확률로 +-1이 나오도록 지정
db = pm_one * np.sqrt(dt)

lhs = mu*dt + sigma*db
time = np.arange(n*T +1) * dt
stock = np.empty( (n*T+1, n_sample_paths)) #stock_price?
stock[0] = s0
for t in range(n*T) :
    stock[t+1] = stock[t] + stock[t]*lhs[t]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.hist(stock[-1], bins=30, density=True) #default는 bins=10. density는 정규화같은 거인 듯.
plt.show()

# %% [markdown]
# log normal 분포...?

# %% [markdown]
# # T를 바꿔보자
# 주의 : n*T가 integer이어야 한다!

# %%
import numpy as np
np.random.seed(10)

s0 = 100 
mu = 0.1 
sigma = 0.3  
T = 1/12 #한 달 뒤를 보겠다!
n = 12*21 #1년은 12달.
dt = 1/n
n_sample_paths = 1000

# %%
pm_one = 2*np.random.binomial(1, 0.5, size=(int(n*T), n_sample_paths)) -1 #50% 확률로 +-1이 나오도록 지정
db = pm_one * np.sqrt(dt)

lhs = mu*dt + sigma*db
time = np.arange(int(n*T) +1) * dt
stock = np.empty( (int(n*T)+1, n_sample_paths)) #stock_price?
stock[0] = s0
for t in range( int(n*T)) :
    stock[t+1] = stock[t] + stock[t]*lhs[t]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

for j in range(5) : #?????? 왜 이렇게 많이 그려집니까...
    plt.plot(time, stock[:, j])

plt.plot(time, stock)
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.hist(stock[-1], bins=30, density=True) #default는 bins=10. density는 정규화같은 거인 듯.
plt.show()

# %% [markdown]
# # Vasicek model
#
# ## $$ dr = a( b - r ) dt + \sigma db $$

# %%
import numpy as np
np.random.seed(337)

s0 = 0.03 
b = 0.05 #target 이자율
a = 0.1 #???? 이건 뭐지
sigma = 0.3  
T = 10 #10년 뒤. . .
n = 12*21 
dt = 1/n
n_sample_paths = 1000
